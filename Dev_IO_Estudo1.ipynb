# %% [markdown]
# <a href="https://colab.research.google.com/github/ftomazetti/desenvolvedor-IO/blob/main/Dev_IO_Estudo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numpy

# %% [markdown]
# # Pandas
